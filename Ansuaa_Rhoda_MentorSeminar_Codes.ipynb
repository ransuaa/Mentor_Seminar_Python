# %% [markdown]
# #NAME: RHODA ANSUAA
#
# ##TOPIC: TRENDS AND DETERMINANTS OF INTERNATIONAL STUDENTS MIGRATION TO RUSSIA
#
# ###MENTOR SEMINAR
# ###PYTHON FOR DATA ANALYSIS

# %%
#Libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load Data
df = pd.read_excel("Rhoda_Raw Data.xlsx")

# %%
#Data Structure inspection
df.head()
# Out:
#           Category Year / Item                     Data / Value  \
# 0              NaN         NaN                              NaN
# 1  Enrolment Trend       ~2019  ~300,000 international students
# 2  Enrolment Trend        2020                         ~315,000
# 3  Enrolment Trend        2021                         ~324,000
# 4  Enrolment Trend        2022                         ~351,500
#
#          Additional Info         Source
# 0                    NaN            NaN
# 1  Pre-pandemic baseline    OECD (2021)
# 2                      —  UNESCO (2025)
# 3                      —  UNESCO (2025)
# 4                      —  Atsyor (2023)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Category         24 non-null     object
#  1   Year / Item      24 non-null     object
#  2   Data / Value     24 non-null     object
#  3   Additional Info  24 non-null     object
#  4   Source           24 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB

# %%
df.describe()
# Out:
#                Category Year / Item Data / Value Additional Info  \
# count                24          24           24              24
# unique                4          24           17              15
# top     Enrolment Trend       ~2019     Score: 8               —
# freq                  7           1            3              10
#
#                      Source
# count                    24
# unique                   13
# top     ICEF Monitor (2023)
# freq                      5

# %%
#Checking Missing Values
df.isnull().sum()
# Out:
# Category           1
# Year / Item        1
# Data / Value       1
# Additional Info    1
# Source             1
# dtype: int64

# %% [markdown]
# #DATA DESCRIPTION AND VISUALIZATION

# %%
#Data from Table 1
data = {
    "Year": [2019, 2020, 2021, 2022, 2023, 2024, 2025],
    "Students": [300000, 315000, 324000, 351500, 376000, 355000, 414000]
}

# %%
#International Students Enrolment
df = pd.DataFrame(data)

plt.figure(figsize=(10,6))
plt.plot(df["Year"], df["Students"], marker="o")
plt.xlabel("Year")
plt.ylabel("Number of International Students")
plt.title("Trends in International Student Enrolment in Russia (2019–2025)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #Interpretation
#
# According to the visualized data in figure 1 above, there is an overall positive structural pattern in Russia’s foreign university inflows, with accelerated growth after 2021, indicating counter-cyclical appeal in response to changes, increased scholarships, and strategic recruitment in Asia and Africa. The likely policy-related realities in 2024, such as visa complexities and exchange rate turbulence, are normalized by the remarkable growth in 2025, with ~414,000 inflows, demonstrating swift market adjustments in finding new destination options for increasingly mobility-restricted students. Russia’s increasing status as an education hub with flexible costs, now in sync with changing SHG, is thereby highlighted.

# %%
# Data from Table 2
data = {
    "Country": ["Kazakhstan", "China", "India", "Uzbekistan", "Belarus/Tajikistan/Turkmenistan/Kyrgyzstan"],
    "Students": [62500, 40000, 31444, 25000, 21500]
}

# %%
#Top Sending Countries
df = pd.DataFrame(data)

plt.figure(figsize=(10,6))
plt.bar(df["Country"], df["Students"])
plt.xlabel("Country")
plt.ylabel("Number of Students")
plt.title("Top Sending Countries to Russia")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# #Interpretation
#
# The figure 2 above indicates that Russia's inward flow of international students demonstrates a marked regionalization, with Kazakhstan, China, and India occupying an unmistakable demand tier, certainly facilitated by their natural proximity, language bonds, and affordability analyses indicated in recent mobility reports. The prominence of CIS nations in particular underscores ongoing post-Soviet associations in these regions, again indicating these institutional associations maintain their powerful role in shaping international mobility. At the same time, China's precipitous growth, coupled with India's expanding figure, reflects Russia's deepening value proposition for Western nations seeking an alternative, albeit in costs now exacerbated in many Western countries by tightening visa policies in such areas as STEM education.

# %%
#Data from Table 3
data = {
    "Determinant": [
        "Cost & scholarships (affordability)",
        "Government quotas & scholarships",
        "Proximity / historical ties (CIS)",
        "Program reputation (medicine, engineering)",
        "Labour market / migration prospects",
        "Language & instruction options",
        "Recruitment networks & diaspora referrals",
        "Geopolitics & visa/entry policy shifts"
    ],
    "Score": [9, 10, 8, 8, 6, 7, 7, 5]
}

# %%
#Pull and Push Determinants
df = pd.DataFrame(data)

plt.figure(figsize=(10,6))
plt.barh(df["Determinant"], df["Score"])
plt.xlabel("Score (1–10)")
plt.ylabel("Determinant")
plt.title("Scores of Pull/Push Determinants")
plt.tight_layout()
plt.show()

# %% [markdown]
# #Interpretation
#
# It appears from the graphic visualization in figure 3 that there is a sharp concentrated mass in regard to affordability and quota support, which shows Russia’s international student inflow is primarily pushed by policy- and cost-related pull forces, not market-based academic competitiveness. By their high levels, scholarships, proximity, and quality in science, tech, engineer, medical studies point to Russia’s competitiveness being grounded in policy-based strategic investments rather than in international recognition prestige. Mid-level factors, such as labor market opportunities and language, record systemic challenges in Russia’s capacity to transform international student flow into permanent migration, weakening overall pull forces in spite of impressive entry incentives. Overall, it becomes visible in drawing patterns there is now an operationalized policy-based recruitment process in Russia’s international student pull policy, yet again hampered by graduated post-education transition outcomes.

# %%
#Data from Table 4
data = {
    "Field of Study": [
        "Medicine",
        "Clinical Medicine / Public Health",
        "Engineering & Technology",
        "Computer / Data Science",
        "Biology & Biotechnology"
    ],
    "Score": [10, 9, 9, 8, 7]
}

# %%
#Field of Study
df = pd.DataFrame(data)

plt.figure(figsize=(10,6))
plt.bar(df["Field of Study"], df["Score"])
plt.xlabel("Field of Study")
plt.ylabel("Popularity Score (1–10)")
plt.title("Popularity of Study Areas among International Students in Russia")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# #Interpretation
#
# Score distribution in figure 4 above represents sharply the preference patterns of the field of study of among international students in Russia, with medicine representing a peak, signifying longstanding demand patterns coupled with Russia’s historical capacity to accommodate substantial state-sponsored intakes. Chaining closely together in second place are clinical medicine/public health and engineering, representing a substantial secondary peak, signifying professional labor market pipeline appeal, along with Russia’s advantage in delivering applied, ‘doable’ training in these areas. The medium-high score in computer/data science reflects an increasingly steep demand curve, aligning with broader international mobility in digital skills, represented in modern, growing markets. By contrast, the medium biotechnology group reflects ‘niche’ research-based migration patterns, largely driven by institutionalization patterns, rather than mainstream appeal.

# %% [markdown]
# #Conclusion
#
# These empirical patterns clearly indicate Russia's international inflows are conditioned by a cost-elastic, policy-dependent mobility structure in which costs, state-imposed quotas, and historical-regional associations have consistently mattered more than market-based intellectual contestations for tertiary education. Data analysis on drivers identifies realignments in international geopolitics, combined with strategic expansion in scholarships, to have strengthened regionalization in Asia and Africa, while CIS nations have remained firmly embedded in institutional, cultural associations. Discipline-based preferences, especially in core areas like medicine and engineering, point to an underlying supply-side specialization paradigm in which demand patterns are driven to align with Russia’s pre-established advantage patterns. These findings clearly point to Russia’s emergent prominence in international mobilities being conditioned not only by its institutional presence, interventions, in world mobilities, but its capacity to resolve post-study transition constraints for integrative mobility.
